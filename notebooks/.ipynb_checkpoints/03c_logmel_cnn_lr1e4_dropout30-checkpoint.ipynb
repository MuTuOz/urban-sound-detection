# %%
from pathlib import Path
import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779374700.130197   55851 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1779374700.158283   55851 pjrt_api.cc:95] PJRT_Api is set for device type gpu
# I0000 00:00:1779374700.161437   55851 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779374701.226795   55851 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
DATASET_DIR = Path("../urban_sound_dataset_split")
METADATA_PATH = DATASET_DIR / "clips_metadata_with_splits.csv"

df = pd.read_csv(METADATA_PATH)

print(df.head())
print("Total clips:", len(df))
print(df["split"].value_counts())
print(df["label"].value_counts())
# Out:
#               clip_filename                            relative_path  \
# 0  bs_ozyegin16_clip025.wav     bird_sounds\bs_ozyegin16_clip025.wav
# 1    pt_plane01_clip007.wav  public_transport\pt_plane01_clip007.wav
# 2    pt_plane02_clip005.wav  public_transport\pt_plane02_clip005.wav
# 3     ft_koru09_clip003.wav          footsteps\ft_koru09_clip003.wav
# 4      pt_bus01_clip034.WAV    public_transport\pt_bus01_clip034.WAV
#
#               label  duration_sec            device  split
# 0       bird_sounds           NaN  Zoom H4essential  train
# 1  public_transport           2.0  Zoom H4essential  train
# 2  public_transport           2.0  Zoom H4essential  train
# 3         footsteps           NaN  Zoom H4essential  train
# 4  public_transport           NaN  Zoom H4essential  train
# Total clips: 1219
# split
# train    853
# val      183
# test     183
# Name: count, dtype: int64
# label
# bird_sounds         175
# public_transport    150
# footsteps           150
# traffic             150
# siren               150
# crowd_chatter       150
# construction        150
# wind_trees          144
# Name: count, dtype: int64

# %%
TARGET_SR = 16000
TARGET_DURATION = 2.0
TARGET_LENGTH = int(TARGET_SR * TARGET_DURATION)

def load_audio_fixed(path, target_sr=TARGET_SR, target_length=TARGET_LENGTH):
    y, sr = librosa.load(path, sr=target_sr, mono=True)

    if len(y) < target_length:
        y = np.pad(y, (0, target_length - len(y)), mode="constant")
    else:
        y = y[:target_length]

    return y, target_sr

# %%
N_MELS = 64
N_FFT = 1024
HOP_LENGTH = 256

def extract_logmel(path):
    y, sr = load_audio_fixed(path)

    mel = librosa.feature.melspectrogram(
        y=y,
        sr=sr,
        n_fft=N_FFT,
        hop_length=HOP_LENGTH,
        n_mels=N_MELS
    )

    log_mel = librosa.power_to_db(mel, ref=np.max)

    # Normalize per sample
    log_mel = (log_mel - log_mel.mean()) / (log_mel.std() + 1e-8)

    return log_mel

# %%
X = []
y = []
splits = []

for idx, row in df.iterrows():
    file_path = DATASET_DIR / row["split"] / row["label"] / row["clip_filename"]

    log_mel = extract_logmel(file_path)

    X.append(log_mel)
    y.append(row["label"])
    splits.append(row["split"])

    if (idx + 1) % 100 == 0:
        print(f"Processed {idx + 1}/{len(df)} clips")

X = np.array(X)
y = np.array(y)
splits = np.array(splits)

print("X shape before channel:", X.shape)

X = X[..., np.newaxis]

print("X shape after channel:", X.shape)
# Out:
# Processed 100/1219 clips
# Processed 200/1219 clips
# Processed 300/1219 clips
# Processed 400/1219 clips
# Processed 500/1219 clips
# Processed 600/1219 clips
# Processed 700/1219 clips
# Processed 800/1219 clips
# Processed 900/1219 clips
# Processed 1000/1219 clips
# Processed 1100/1219 clips
# Processed 1200/1219 clips
# X shape before channel: (1219, 64, 126)
# X shape after channel: (1219, 64, 126, 1)

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

num_classes = len(label_encoder.classes_)

print("Classes:")
for i, cls in enumerate(label_encoder.classes_):
    print(i, cls)

print("Number of classes:", num_classes)

train_mask = splits == "train"
val_mask = splits == "val"
test_mask = splits == "test"

X_train = X[train_mask]
X_val = X[val_mask]
X_test = X[test_mask]

y_train = y_encoded[train_mask]
y_val = y_encoded[val_mask]
y_test = y_encoded[test_mask]

print("Train:", X_train.shape, y_train.shape)
print("Val:", X_val.shape, y_val.shape)
print("Test:", X_test.shape, y_test.shape)
# Out:
# Classes:
# 0 bird_sounds
# 1 construction
# 2 crowd_chatter
# 3 footsteps
# 4 public_transport
# 5 siren
# 6 traffic
# 7 wind_trees
# Number of classes: 8
# Train: (853, 64, 126, 1) (853,)
# Val: (183, 64, 126, 1) (183,)
# Test: (183, 64, 126, 1) (183,)

# %%
input_shape = X_train.shape[1:]

def build_audio_cnn(input_shape, num_classes, dropout_dense=0.30):
    model = models.Sequential([
        layers.Input(shape=input_shape),

        layers.Conv2D(32, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.ReLU(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.10),

        layers.Conv2D(64, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.ReLU(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.15),

        layers.Conv2D(128, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.ReLU(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.20),

        layers.GlobalAveragePooling2D(),

        layers.Dense(128, activation="relu"),
        layers.Dropout(dropout_dense),

        layers.Dense(num_classes, activation="softmax")
    ])

    return model

model = build_audio_cnn(input_shape, num_classes)
model.summary()
# Out:
# E0000 00:00:1779374720.811400   55851 cuda_executor.cc:1525] Could not get kernel mode driver version: (INVALID_ARGUMENT: Version does not match the format X.Y.Z)
# W0000 00:00:1779374720.877998   55851 gpu_device.cc:2364] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 64, 126, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 126, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 64, 126, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 63, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 63, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 32, 63, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 31, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16, 31, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 31, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 31, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 16, 31, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 8, 15, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 8, 15, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 111,112 (434.03 KB)
#  Trainable params: 110,664 (432.28 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
model = build_audio_cnn(input_shape, num_classes, dropout_dense=0.30)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
early_stop = callbacks.EarlyStopping(
    monitor="val_accuracy",
    patience=15,
    mode="max",
    restore_best_weights=True
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

history = model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.2145 - loss: 2.0363 - val_accuracy: 0.1585 - val_loss: 2.0577 - learning_rate: 1.0000e-04
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.3411 - loss: 1.7772 - val_accuracy: 0.1475 - val_loss: 2.0505 - learning_rate: 1.0000e-04
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.4549 - loss: 1.5642 - val_accuracy: 0.1475 - val_loss: 2.0444 - learning_rate: 1.0000e-04
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.5123 - loss: 1.4508 - val_accuracy: 0.2131 - val_loss: 2.0402 - learning_rate: 1.0000e-04
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.5733 - loss: 1.3360 - val_accuracy: 0.2131 - val_loss: 2.0488 - learning_rate: 1.0000e-04
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.5991 - loss: 1.2575 - val_accuracy: 0.1530 - val_loss: 2.0514 - learning_rate: 1.0000e-04
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.6389 - loss: 1.1691 - val_accuracy: 0.1202 - val_loss: 2.0784 - learning_rate: 1.0000e-04
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.6928 - loss: 1.0752 - val_accuracy: 0.1639 - val_loss: 2.1091 - learning_rate: 1.0000e-04
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.6987 - loss: 1.0521
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.7175 - loss: 1.0208 - val_accuracy: 0.2459 - val_loss: 2.1355 - learning_rate: 1.0000e-04
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.7233 - loss: 0.9667 - val_accuracy: 0.2623 - val_loss: 2.1105 - learning_rate: 5.0000e-05
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.7175 - loss: 0.9833 - val_accuracy: 0.2842 - val_loss: 2.0759 - learning_rate: 5.0000e-05
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.7456 - loss: 0.9399 - val_accuracy: 0.2951 - val_loss: 2.0234 - learning_rate: 5.0000e-05
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.7397 - loss: 0.9132 - val_accuracy: 0.3115 - val_loss: 1.9460 - learning_rate: 5.0000e-05
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.7620 - loss: 0.8752 - val_accuracy: 0.3224 - val_loss: 1.8709 - learning_rate: 5.0000e-05
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.7538 - loss: 0.8805 - val_accuracy: 0.3333 - val_loss: 1.7559 - learning_rate: 5.0000e-05
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.7421 - loss: 0.8605 - val_accuracy: 0.3716 - val_loss: 1.6235 - learning_rate: 5.0000e-05
# Epoch 17/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.7620 - loss: 0.8401 - val_accuracy: 0.4044 - val_loss: 1.4640 - learning_rate: 5.0000e-05
# Epoch 18/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.7831 - loss: 0.8161 - val_accuracy: 0.4208 - val_loss: 1.3870 - learning_rate: 5.0000e-05
# Epoch 19/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.7925 - loss: 0.8094 - val_accuracy: 0.4426 - val_loss: 1.2511 - learning_rate: 5.0000e-05
# Epoch 20/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.7726 - loss: 0.7930 - val_accuracy: 0.5082 - val_loss: 1.1449 - learning_rate: 5.0000e-05
# Epoch 21/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.7960 - loss: 0.7592 - val_accuracy: 0.5792 - val_loss: 1.0269 - learning_rate: 5.0000e-05
# Epoch 22/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.7808 - loss: 0.7633 - val_accuracy: 0.6393 - val_loss: 0.9265 - learning_rate: 5.0000e-05
# Epoch 23/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.7866 - loss: 0.7715 - val_accuracy: 0.6667 - val_loss: 0.8849 - learning_rate: 5.0000e-05
# Epoch 24/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.7960 - loss: 0.7356 - val_accuracy: 0.6940 - val_loss: 0.8425 - learning_rate: 5.0000e-05
# Epoch 25/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.7913 - loss: 0.7458 - val_accuracy: 0.7814 - val_loss: 0.7614 - learning_rate: 5.0000e-05
# Epoch 26/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.7984 - loss: 0.7236 - val_accuracy: 0.8033 - val_loss: 0.7447 - learning_rate: 5.0000e-05
# Epoch 27/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.8113 - loss: 0.6890 - val_accuracy: 0.8306 - val_loss: 0.7066 - learning_rate: 5.0000e-05
# Epoch 28/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.7995 - loss: 0.7077 - val_accuracy: 0.8579 - val_loss: 0.6882 - learning_rate: 5.0000e-05
# Epoch 29/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8077 - loss: 0.6668 - val_accuracy: 0.8470 - val_loss: 0.6703 - learning_rate: 5.0000e-05
# Epoch 30/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.8370 - loss: 0.6433 - val_accuracy: 0.8579 - val_loss: 0.6532 - learning_rate: 5.0000e-05
# Epoch 31/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.8218 - loss: 0.6497 - val_accuracy: 0.8470 - val_loss: 0.6355 - learning_rate: 5.0000e-05
# Epoch 32/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8288 - loss: 0.6397 - val_accuracy: 0.8634 - val_loss: 0.6304 - learning_rate: 5.0000e-05
# Epoch 33/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8441 - loss: 0.6118 - val_accuracy: 0.8689 - val_loss: 0.6133 - learning_rate: 5.0000e-05
# Epoch 34/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8300 - loss: 0.6280 - val_accuracy: 0.8525 - val_loss: 0.6196 - learning_rate: 5.0000e-05
# Epoch 35/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8464 - loss: 0.5863 - val_accuracy: 0.8579 - val_loss: 0.5993 - learning_rate: 5.0000e-05
# Epoch 36/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8206 - loss: 0.6104 - val_accuracy: 0.8743 - val_loss: 0.5850 - learning_rate: 5.0000e-05
# Epoch 37/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8265 - loss: 0.5973 - val_accuracy: 0.8743 - val_loss: 0.5744 - learning_rate: 5.0000e-05
# Epoch 38/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8406 - loss: 0.5732 - val_accuracy: 0.8743 - val_loss: 0.5683 - learning_rate: 5.0000e-05
# Epoch 39/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.8394 - loss: 0.5883 - val_accuracy: 0.8798 - val_loss: 0.5574 - learning_rate: 5.0000e-05
# Epoch 40/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.8394 - loss: 0.5674 - val_accuracy: 0.9016 - val_loss: 0.5477 - learning_rate: 5.0000e-05
# Epoch 41/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8265 - loss: 0.5884 - val_accuracy: 0.8962 - val_loss: 0.5447 - learning_rate: 5.0000e-05
# Epoch 42/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8734 - loss: 0.5276 - val_accuracy: 0.8743 - val_loss: 0.5391 - learning_rate: 5.0000e-05
# Epoch 43/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8675 - loss: 0.5288 - val_accuracy: 0.8907 - val_loss: 0.5407 - learning_rate: 5.0000e-05
# Epoch 44/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8558 - loss: 0.5233 - val_accuracy: 0.8743 - val_loss: 0.5334 - learning_rate: 5.0000e-05
# Epoch 45/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8722 - loss: 0.5216 - val_accuracy: 0.8962 - val_loss: 0.5202 - learning_rate: 5.0000e-05
# Epoch 46/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8769 - loss: 0.5104 - val_accuracy: 0.8907 - val_loss: 0.4983 - learning_rate: 5.0000e-05
# Epoch 47/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.8687 - loss: 0.5147 - val_accuracy: 0.9071 - val_loss: 0.4870 - learning_rate: 5.0000e-05
# Epoch 48/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.8581 - loss: 0.5033 - val_accuracy: 0.9016 - val_loss: 0.4950 - learning_rate: 5.0000e-05
# Epoch 49/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8511 - loss: 0.4996 - val_accuracy: 0.9016 - val_loss: 0.4928 - learning_rate: 5.0000e-05
# Epoch 50/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8687 - loss: 0.4635 - val_accuracy: 0.8962 - val_loss: 0.4742 - learning_rate: 5.0000e-05
# Epoch 51/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8664 - loss: 0.4807 - val_accuracy: 0.9016 - val_loss: 0.4718 - learning_rate: 5.0000e-05
# Epoch 52/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8664 - loss: 0.4882 - val_accuracy: 0.8962 - val_loss: 0.4798 - learning_rate: 5.0000e-05
# Epoch 53/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8558 - loss: 0.4755 - val_accuracy: 0.9126 - val_loss: 0.4551 - learning_rate: 5.0000e-05
# Epoch 54/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8722 - loss: 0.4774 - val_accuracy: 0.8962 - val_loss: 0.4521 - learning_rate: 5.0000e-05
# Epoch 55/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.8593 - loss: 0.4799 - val_accuracy: 0.8907 - val_loss: 0.4648 - learning_rate: 5.0000e-05
# Epoch 56/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8804 - loss: 0.4533 - val_accuracy: 0.9126 - val_loss: 0.4511 - learning_rate: 5.0000e-05
# Epoch 57/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8816 - loss: 0.4424 - val_accuracy: 0.8962 - val_loss: 0.4575 - learning_rate: 5.0000e-05
# Epoch 58/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.8875 - loss: 0.4443 - val_accuracy: 0.9126 - val_loss: 0.4350 - learning_rate: 5.0000e-05
# Epoch 59/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8816 - loss: 0.4448 - val_accuracy: 0.9016 - val_loss: 0.4369 - learning_rate: 5.0000e-05
# Epoch 60/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8734 - loss: 0.4176 - val_accuracy: 0.8962 - val_loss: 0.4325 - learning_rate: 5.0000e-05
# Epoch 61/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.8722 - loss: 0.4365 - val_accuracy: 0.8962 - val_loss: 0.4476 - learning_rate: 5.0000e-05
# Epoch 62/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8699 - loss: 0.4359 - val_accuracy: 0.9071 - val_loss: 0.4182 - learning_rate: 5.0000e-05
# Epoch 63/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.8804 - loss: 0.4318 - val_accuracy: 0.9016 - val_loss: 0.4284 - learning_rate: 5.0000e-05
# Epoch 64/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8816 - loss: 0.4206 - val_accuracy: 0.9180 - val_loss: 0.4190 - learning_rate: 5.0000e-05
# Epoch 65/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8898 - loss: 0.4141 - val_accuracy: 0.9071 - val_loss: 0.4225 - learning_rate: 5.0000e-05
# Epoch 66/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8675 - loss: 0.4325 - val_accuracy: 0.9235 - val_loss: 0.3948 - learning_rate: 5.0000e-05
# Epoch 67/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.8769 - loss: 0.4180 - val_accuracy: 0.9016 - val_loss: 0.4172 - learning_rate: 5.0000e-05
# Epoch 68/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8957 - loss: 0.4070 - val_accuracy: 0.9016 - val_loss: 0.4029 - learning_rate: 5.0000e-05
# Epoch 69/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8746 - loss: 0.4231 - val_accuracy: 0.9235 - val_loss: 0.3863 - learning_rate: 5.0000e-05
# Epoch 70/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8804 - loss: 0.4022 - val_accuracy: 0.9071 - val_loss: 0.4353 - learning_rate: 5.0000e-05
# Epoch 71/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8828 - loss: 0.4048 - val_accuracy: 0.9399 - val_loss: 0.3787 - learning_rate: 5.0000e-05
# Epoch 72/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8945 - loss: 0.3912 - val_accuracy: 0.9126 - val_loss: 0.4008 - learning_rate: 5.0000e-05
# Epoch 73/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8804 - loss: 0.3928 - val_accuracy: 0.9290 - val_loss: 0.3819 - learning_rate: 5.0000e-05
# Epoch 74/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8792 - loss: 0.3935 - val_accuracy: 0.9180 - val_loss: 0.3790 - learning_rate: 5.0000e-05
# Epoch 75/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8863 - loss: 0.3735 - val_accuracy: 0.9071 - val_loss: 0.3852 - learning_rate: 5.0000e-05
# Epoch 76/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8982 - loss: 0.3662
# Epoch 76: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.8980 - loss: 0.3769 - val_accuracy: 0.9016 - val_loss: 0.3862 - learning_rate: 5.0000e-05
# Epoch 77/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8910 - loss: 0.3733 - val_accuracy: 0.9126 - val_loss: 0.3742 - learning_rate: 2.5000e-05
# Epoch 78/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8898 - loss: 0.3785 - val_accuracy: 0.9235 - val_loss: 0.3693 - learning_rate: 2.5000e-05
# Epoch 79/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.9097 - loss: 0.3541 - val_accuracy: 0.9126 - val_loss: 0.3731 - learning_rate: 2.5000e-05
# Epoch 80/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.8992 - loss: 0.3608 - val_accuracy: 0.9180 - val_loss: 0.3653 - learning_rate: 2.5000e-05
# Epoch 81/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8945 - loss: 0.3674 - val_accuracy: 0.9071 - val_loss: 0.3701 - learning_rate: 2.5000e-05
# Epoch 82/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.9062 - loss: 0.3721 - val_accuracy: 0.9180 - val_loss: 0.3654 - learning_rate: 2.5000e-05
# Epoch 83/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.9004 - loss: 0.3492 - val_accuracy: 0.9235 - val_loss: 0.3680 - learning_rate: 2.5000e-05
# Epoch 84/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8968 - loss: 0.3608 - val_accuracy: 0.9399 - val_loss: 0.3567 - learning_rate: 2.5000e-05
# Epoch 85/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.9050 - loss: 0.3560 - val_accuracy: 0.9235 - val_loss: 0.3543 - learning_rate: 2.5000e-05
# Epoch 86/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.8921 - loss: 0.3606 - val_accuracy: 0.9180 - val_loss: 0.3585 - learning_rate: 2.5000e-05

# %%
plt.figure(figsize=(8, 4))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("CNN Training and Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("CNN Training and Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.tight_layout()
plt.show()

# %%
val_probs = model.predict(X_val)
val_pred = np.argmax(val_probs, axis=1)

val_acc = accuracy_score(y_val, val_pred)
val_f1 = f1_score(y_val, val_pred, average="macro")

print("Validation Accuracy:", val_acc)
print("Validation Macro-F1:", val_f1)

print(classification_report(
    y_val,
    val_pred,
    target_names=label_encoder.classes_
))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Validation Accuracy: 0.9398907103825137
# Validation Macro-F1: 0.939927332587509
#                   precision    recall  f1-score   support
#
#      bird_sounds       0.93      0.96      0.95        27
#     construction       0.85      1.00      0.92        23
#    crowd_chatter       0.91      0.91      0.91        22
#        footsteps       0.92      1.00      0.96        22
# public_transport       0.95      0.95      0.95        22
#            siren       1.00      0.87      0.93        23
#          traffic       1.00      0.95      0.98        22
#       wind_trees       1.00      0.86      0.93        22
#
#         accuracy                           0.94       183
#        macro avg       0.95      0.94      0.94       183
#     weighted avg       0.94      0.94      0.94       183

# %%
test_probs = model.predict(X_test)
test_pred = np.argmax(test_probs, axis=1)

test_acc = accuracy_score(y_test, test_pred)
test_f1 = f1_score(y_test, test_pred, average="macro")

print("Test Accuracy:", test_acc)
print("Test Macro-F1:", test_f1)

print(classification_report(
    y_test,
    test_pred,
    target_names=label_encoder.classes_
))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Test Accuracy: 0.9289617486338798
# Test Macro-F1: 0.9262627603058525
#                   precision    recall  f1-score   support
#
#      bird_sounds       0.96      1.00      0.98        26
#     construction       0.92      1.00      0.96        22
#    crowd_chatter       0.91      0.91      0.91        23
#        footsteps       0.82      1.00      0.90        23
# public_transport       0.87      0.87      0.87        23
#            siren       1.00      1.00      1.00        22
#          traffic       1.00      0.91      0.95        23
#       wind_trees       1.00      0.71      0.83        21
#
#         accuracy                           0.93       183
#        macro avg       0.94      0.93      0.93       183
#     weighted avg       0.93      0.93      0.93       183

# %%
cm = confusion_matrix(y_test, test_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=label_encoder.classes_,
    yticklabels=label_encoder.classes_
)

plt.title("Log-mel Spectrogram + CNN (lr1e-4 + dropout = 0.3) Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
RESULTS_DIR = Path("../results")
MODELS_DIR = Path("../models")

RESULTS_DIR.mkdir(exist_ok=True)
MODELS_DIR.mkdir(exist_ok=True)

model.save(MODELS_DIR / "logmel_cnn_lr1e4_dropout30.keras")

cnn_results = {
    "model": "Log-mel CNN lr=1e-4 dropout=0.30",
    "experiment": "lr1e-4_dropout30",
    "features": "64-bin log-mel spectrogram",
    "validation_accuracy": val_acc,
    "validation_macro_f1": val_f1,
    "test_accuracy": test_acc,
    "test_macro_f1": test_f1,
    "architecture": "Conv32-Conv64-Conv128-GAP-Dense128",
    "learning_rate": 1e-4,
    "batch_size": 32,
    "dropout_dense": 0.30,
    "notes": "Tests effect of weaker dropout regularization"
}

cnn_results_df = pd.DataFrame([cnn_results])

cnn_results_df.to_csv(
    RESULTS_DIR / "logmel_cnn_lr1e4_dropout30_results.csv",
    index=False
)

cnn_results_df
# Out:
#                               model        experiment  \
# 0  Log-mel CNN lr=1e-4 dropout=0.30  lr1e-4_dropout30
#
#                      features  validation_accuracy  validation_macro_f1  \
# 0  64-bin log-mel spectrogram             0.939891             0.939927
#
#    test_accuracy  test_macro_f1                        architecture  \
# 0       0.928962       0.926263  Conv32-Conv64-Conv128-GAP-Dense128
#
#    learning_rate  batch_size  dropout_dense  \
# 0         0.0001          32            0.3
#
#                                            notes
# 0  Tests effect of weaker dropout regularization

# %%
baseline_path = RESULTS_DIR / "mfcc_mlp_baseline_results.csv"
cnn_dropout50_path = RESULTS_DIR / "logmel_cnn_lr1e4_dropout50_results.csv"
cnn_dropout30_path = RESULTS_DIR / "logmel_cnn_lr1e4_dropout30_results.csv"

baseline_df = pd.read_csv(baseline_path)
cnn_dropout50_df = pd.read_csv(cnn_dropout50_path)
cnn_dropout30_df = pd.read_csv(cnn_dropout30_path)

comparison_df = pd.concat(
    [baseline_df, cnn_dropout50_df, cnn_dropout30_df],
    ignore_index=True
)

comparison_df

plt.figure(figsize=(10, 4))
plt.bar(comparison_df["model"], comparison_df["test_macro_f1"])
plt.title("Model Comparison: Test Macro-F1")
plt.ylabel("Test Macro-F1")
plt.ylim(0, 1)
plt.xticks(rotation=30, ha="right")
plt.tight_layout()
plt.show()
