# %%
from pathlib import Path
import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779372749.181282   39714 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1779372749.543111   39714 pjrt_api.cc:95] PJRT_Api is set for device type gpu
# I0000 00:00:1779372749.624232   39714 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779372751.735513   39714 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
DATASET_DIR = Path("../urban_sound_dataset_split")
METADATA_PATH = DATASET_DIR / "clips_metadata_with_splits.csv"

df = pd.read_csv(METADATA_PATH)

print(df.head())
print("Total clips:", len(df))
print(df["split"].value_counts())
print(df["label"].value_counts())
# Out:
#               clip_filename                            relative_path  \
# 0  bs_ozyegin16_clip025.wav     bird_sounds\bs_ozyegin16_clip025.wav
# 1    pt_plane01_clip007.wav  public_transport\pt_plane01_clip007.wav
# 2    pt_plane02_clip005.wav  public_transport\pt_plane02_clip005.wav
# 3     ft_koru09_clip003.wav          footsteps\ft_koru09_clip003.wav
# 4      pt_bus01_clip034.WAV    public_transport\pt_bus01_clip034.WAV
#
#               label  duration_sec            device  split
# 0       bird_sounds           NaN  Zoom H4essential  train
# 1  public_transport           2.0  Zoom H4essential  train
# 2  public_transport           2.0  Zoom H4essential  train
# 3         footsteps           NaN  Zoom H4essential  train
# 4  public_transport           NaN  Zoom H4essential  train
# Total clips: 1219
# split
# train    853
# val      183
# test     183
# Name: count, dtype: int64
# label
# bird_sounds         175
# public_transport    150
# footsteps           150
# traffic             150
# siren               150
# crowd_chatter       150
# construction        150
# wind_trees          144
# Name: count, dtype: int64

# %%
TARGET_SR = 16000
TARGET_DURATION = 2.0
TARGET_LENGTH = int(TARGET_SR * TARGET_DURATION)

def load_audio_fixed(path, target_sr=TARGET_SR, target_length=TARGET_LENGTH):
    y, sr = librosa.load(path, sr=target_sr, mono=True)

    if len(y) < target_length:
        y = np.pad(y, (0, target_length - len(y)), mode="constant")
    else:
        y = y[:target_length]

    return y, target_sr

# %%
N_MELS = 64
N_FFT = 1024
HOP_LENGTH = 256

def extract_logmel(path):
    y, sr = load_audio_fixed(path)

    mel = librosa.feature.melspectrogram(
        y=y,
        sr=sr,
        n_fft=N_FFT,
        hop_length=HOP_LENGTH,
        n_mels=N_MELS
    )

    log_mel = librosa.power_to_db(mel, ref=np.max)

    # Normalize per sample
    log_mel = (log_mel - log_mel.mean()) / (log_mel.std() + 1e-8)

    return log_mel

# %%
X = []
y = []
splits = []

for idx, row in df.iterrows():
    file_path = DATASET_DIR / row["split"] / row["label"] / row["clip_filename"]

    log_mel = extract_logmel(file_path)

    X.append(log_mel)
    y.append(row["label"])
    splits.append(row["split"])

    if (idx + 1) % 100 == 0:
        print(f"Processed {idx + 1}/{len(df)} clips")

X = np.array(X)
y = np.array(y)
splits = np.array(splits)

print("X shape before channel:", X.shape)

X = X[..., np.newaxis]

print("X shape after channel:", X.shape)
# Out:
# Processed 100/1219 clips
# Processed 200/1219 clips
# Processed 300/1219 clips
# Processed 400/1219 clips
# Processed 500/1219 clips
# Processed 600/1219 clips
# Processed 700/1219 clips
# Processed 800/1219 clips
# Processed 900/1219 clips
# Processed 1000/1219 clips
# Processed 1100/1219 clips
# Processed 1200/1219 clips
# X shape before channel: (1219, 64, 126)
# X shape after channel: (1219, 64, 126, 1)

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

num_classes = len(label_encoder.classes_)

print("Classes:")
for i, cls in enumerate(label_encoder.classes_):
    print(i, cls)

print("Number of classes:", num_classes)

train_mask = splits == "train"
val_mask = splits == "val"
test_mask = splits == "test"

X_train = X[train_mask]
X_val = X[val_mask]
X_test = X[test_mask]

y_train = y_encoded[train_mask]
y_val = y_encoded[val_mask]
y_test = y_encoded[test_mask]

print("Train:", X_train.shape, y_train.shape)
print("Val:", X_val.shape, y_val.shape)
print("Test:", X_test.shape, y_test.shape)
# Out:
# Classes:
# 0 bird_sounds
# 1 construction
# 2 crowd_chatter
# 3 footsteps
# 4 public_transport
# 5 siren
# 6 traffic
# 7 wind_trees
# Number of classes: 8
# Train: (853, 64, 126, 1) (853,)
# Val: (183, 64, 126, 1) (183,)
# Test: (183, 64, 126, 1) (183,)

# %%
input_shape = X_train.shape[1:]

def build_audio_cnn(input_shape, num_classes, dropout_dense=0.30):
    model = models.Sequential([
        layers.Input(shape=input_shape),

        layers.Conv2D(32, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.ReLU(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.10),

        layers.Conv2D(64, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.ReLU(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.15),

        layers.Conv2D(128, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.ReLU(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.20),

        layers.GlobalAveragePooling2D(),

        layers.Dense(128, activation="relu"),
        layers.Dropout(dropout_dense),

        layers.Dense(num_classes, activation="softmax")
    ])

    return model

model = build_audio_cnn(input_shape, num_classes)
model.summary()
# Out:
# E0000 00:00:1779372934.774568   39714 cuda_executor.cc:1525] Could not get kernel mode driver version: (INVALID_ARGUMENT: Version does not match the format X.Y.Z)
# W0000 00:00:1779372935.065403   39714 gpu_device.cc:2364] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 64, 126, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 126, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 64, 126, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 63, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 63, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 32, 63, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 31, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16, 31, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 31, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 31, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 16, 31, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 8, 15, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 8, 15, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 111,112 (434.03 KB)
#  Trainable params: 110,664 (432.28 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
model = build_audio_cnn(input_shape, num_classes, dropout_dense=0.50)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
early_stop = callbacks.EarlyStopping(
    monitor="val_accuracy",
    patience=15,
    mode="max",
    restore_best_weights=True
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

history = model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.1547 - loss: 2.3943 - val_accuracy: 0.1967 - val_loss: 2.0654 - learning_rate: 1.0000e-04
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.2825 - loss: 1.9315 - val_accuracy: 0.1202 - val_loss: 2.0592 - learning_rate: 1.0000e-04
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.3494 - loss: 1.7207 - val_accuracy: 0.1202 - val_loss: 2.0684 - learning_rate: 1.0000e-04
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.4115 - loss: 1.5723 - val_accuracy: 0.1202 - val_loss: 2.0898 - learning_rate: 1.0000e-04
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.4478 - loss: 1.5062 - val_accuracy: 0.1202 - val_loss: 2.1032 - learning_rate: 1.0000e-04
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.5053 - loss: 1.4086 - val_accuracy: 0.2022 - val_loss: 2.1141 - learning_rate: 1.0000e-04
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.5451 - loss: 1.3381
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.5451 - loss: 1.3356 - val_accuracy: 0.1421 - val_loss: 2.1144 - learning_rate: 1.0000e-04
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.5674 - loss: 1.2916 - val_accuracy: 0.1530 - val_loss: 2.0893 - learning_rate: 5.0000e-05
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.5721 - loss: 1.2640 - val_accuracy: 0.1913 - val_loss: 2.0643 - learning_rate: 5.0000e-05
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.5768 - loss: 1.2334 - val_accuracy: 0.2623 - val_loss: 2.0244 - learning_rate: 5.0000e-05
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.6178 - loss: 1.1904 - val_accuracy: 0.2842 - val_loss: 1.9878 - learning_rate: 5.0000e-05
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6084 - loss: 1.1858 - val_accuracy: 0.3224 - val_loss: 1.9379 - learning_rate: 5.0000e-05
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.6424 - loss: 1.1329 - val_accuracy: 0.3552 - val_loss: 1.8681 - learning_rate: 5.0000e-05
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.6319 - loss: 1.1468 - val_accuracy: 0.3934 - val_loss: 1.8074 - learning_rate: 5.0000e-05
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.6342 - loss: 1.1151 - val_accuracy: 0.4153 - val_loss: 1.7252 - learning_rate: 5.0000e-05
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.6471 - loss: 1.0897 - val_accuracy: 0.4481 - val_loss: 1.6327 - learning_rate: 5.0000e-05
# Epoch 17/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.6518 - loss: 1.0978 - val_accuracy: 0.4754 - val_loss: 1.5577 - learning_rate: 5.0000e-05
# Epoch 18/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.6600 - loss: 1.0609 - val_accuracy: 0.4754 - val_loss: 1.4732 - learning_rate: 5.0000e-05
# Epoch 19/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.6600 - loss: 1.0624 - val_accuracy: 0.5137 - val_loss: 1.3677 - learning_rate: 5.0000e-05
# Epoch 20/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.6811 - loss: 1.0345 - val_accuracy: 0.5410 - val_loss: 1.2933 - learning_rate: 5.0000e-05
# Epoch 21/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.6624 - loss: 1.0329 - val_accuracy: 0.5683 - val_loss: 1.2170 - learning_rate: 5.0000e-05
# Epoch 22/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.6893 - loss: 0.9918 - val_accuracy: 0.5956 - val_loss: 1.1545 - learning_rate: 5.0000e-05
# Epoch 23/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.6975 - loss: 0.9876 - val_accuracy: 0.6284 - val_loss: 1.0785 - learning_rate: 5.0000e-05
# Epoch 24/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.7057 - loss: 0.9525 - val_accuracy: 0.6284 - val_loss: 1.0534 - learning_rate: 5.0000e-05
# Epoch 25/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.7315 - loss: 0.9358 - val_accuracy: 0.6667 - val_loss: 1.0042 - learning_rate: 5.0000e-05
# Epoch 26/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.7186 - loss: 0.9325 - val_accuracy: 0.6885 - val_loss: 0.9768 - learning_rate: 5.0000e-05
# Epoch 27/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.7046 - loss: 0.9280 - val_accuracy: 0.7268 - val_loss: 0.9510 - learning_rate: 5.0000e-05
# Epoch 28/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.7444 - loss: 0.8868 - val_accuracy: 0.7158 - val_loss: 0.9390 - learning_rate: 5.0000e-05
# Epoch 29/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.7339 - loss: 0.8602 - val_accuracy: 0.7486 - val_loss: 0.9184 - learning_rate: 5.0000e-05
# Epoch 30/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.7245 - loss: 0.8830 - val_accuracy: 0.7650 - val_loss: 0.8836 - learning_rate: 5.0000e-05
# Epoch 31/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.7538 - loss: 0.8741 - val_accuracy: 0.7650 - val_loss: 0.8699 - learning_rate: 5.0000e-05
# Epoch 32/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.7374 - loss: 0.8645 - val_accuracy: 0.7760 - val_loss: 0.8489 - learning_rate: 5.0000e-05
# Epoch 33/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.7526 - loss: 0.8452 - val_accuracy: 0.8142 - val_loss: 0.8134 - learning_rate: 5.0000e-05
# Epoch 34/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.7562 - loss: 0.8387 - val_accuracy: 0.8142 - val_loss: 0.7929 - learning_rate: 5.0000e-05
# Epoch 35/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.7386 - loss: 0.8338 - val_accuracy: 0.8197 - val_loss: 0.7884 - learning_rate: 5.0000e-05
# Epoch 36/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.7691 - loss: 0.8022 - val_accuracy: 0.8197 - val_loss: 0.7901 - learning_rate: 5.0000e-05
# Epoch 37/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.7538 - loss: 0.8075 - val_accuracy: 0.8470 - val_loss: 0.7615 - learning_rate: 5.0000e-05
# Epoch 38/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.7726 - loss: 0.7855 - val_accuracy: 0.8306 - val_loss: 0.7508 - learning_rate: 5.0000e-05
# Epoch 39/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.7796 - loss: 0.7945 - val_accuracy: 0.8470 - val_loss: 0.7343 - learning_rate: 5.0000e-05
# Epoch 40/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.7620 - loss: 0.7655 - val_accuracy: 0.8306 - val_loss: 0.7345 - learning_rate: 5.0000e-05
# Epoch 41/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.7784 - loss: 0.7485 - val_accuracy: 0.8579 - val_loss: 0.7132 - learning_rate: 5.0000e-05
# Epoch 42/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.7831 - loss: 0.7330 - val_accuracy: 0.8634 - val_loss: 0.6972 - learning_rate: 5.0000e-05
# Epoch 43/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.7960 - loss: 0.7101 - val_accuracy: 0.8525 - val_loss: 0.6888 - learning_rate: 5.0000e-05
# Epoch 44/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8077 - loss: 0.7201 - val_accuracy: 0.8634 - val_loss: 0.6762 - learning_rate: 5.0000e-05
# Epoch 45/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.7808 - loss: 0.7281 - val_accuracy: 0.8634 - val_loss: 0.6596 - learning_rate: 5.0000e-05
# Epoch 46/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8089 - loss: 0.6904 - val_accuracy: 0.8634 - val_loss: 0.6635 - learning_rate: 5.0000e-05
# Epoch 47/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.7913 - loss: 0.7002 - val_accuracy: 0.8634 - val_loss: 0.6538 - learning_rate: 5.0000e-05
# Epoch 48/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.8042 - loss: 0.6756 - val_accuracy: 0.8579 - val_loss: 0.6371 - learning_rate: 5.0000e-05
# Epoch 49/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.7890 - loss: 0.7108 - val_accuracy: 0.8579 - val_loss: 0.6466 - learning_rate: 5.0000e-05
# Epoch 50/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.7902 - loss: 0.6786 - val_accuracy: 0.8689 - val_loss: 0.6241 - learning_rate: 5.0000e-05
# Epoch 51/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.8030 - loss: 0.6691 - val_accuracy: 0.8525 - val_loss: 0.6156 - learning_rate: 5.0000e-05
# Epoch 52/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.8019 - loss: 0.6870 - val_accuracy: 0.8470 - val_loss: 0.6234 - learning_rate: 5.0000e-05
# Epoch 53/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.8019 - loss: 0.6722 - val_accuracy: 0.8579 - val_loss: 0.6077 - learning_rate: 5.0000e-05
# Epoch 54/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.8159 - loss: 0.6516 - val_accuracy: 0.8525 - val_loss: 0.5905 - learning_rate: 5.0000e-05
# Epoch 55/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8007 - loss: 0.6661 - val_accuracy: 0.8689 - val_loss: 0.5830 - learning_rate: 5.0000e-05
# Epoch 56/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.8277 - loss: 0.6314 - val_accuracy: 0.8634 - val_loss: 0.5794 - learning_rate: 5.0000e-05
# Epoch 57/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.8066 - loss: 0.6199 - val_accuracy: 0.8689 - val_loss: 0.5818 - learning_rate: 5.0000e-05
# Epoch 58/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8324 - loss: 0.5948 - val_accuracy: 0.8634 - val_loss: 0.5752 - learning_rate: 5.0000e-05
# Epoch 59/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.8113 - loss: 0.6249 - val_accuracy: 0.8634 - val_loss: 0.5615 - learning_rate: 5.0000e-05
# Epoch 60/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8183 - loss: 0.6102 - val_accuracy: 0.8743 - val_loss: 0.5581 - learning_rate: 5.0000e-05
# Epoch 61/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8288 - loss: 0.6109 - val_accuracy: 0.8852 - val_loss: 0.5435 - learning_rate: 5.0000e-05
# Epoch 62/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.8159 - loss: 0.6039 - val_accuracy: 0.8907 - val_loss: 0.5318 - learning_rate: 5.0000e-05
# Epoch 63/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.8242 - loss: 0.6021 - val_accuracy: 0.8798 - val_loss: 0.5492 - learning_rate: 5.0000e-05
# Epoch 64/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8476 - loss: 0.5620 - val_accuracy: 0.8798 - val_loss: 0.5306 - learning_rate: 5.0000e-05
# Epoch 65/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8476 - loss: 0.5692 - val_accuracy: 0.8907 - val_loss: 0.5193 - learning_rate: 5.0000e-05
# Epoch 66/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8312 - loss: 0.5679 - val_accuracy: 0.8907 - val_loss: 0.5101 - learning_rate: 5.0000e-05
# Epoch 67/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8218 - loss: 0.5740 - val_accuracy: 0.8962 - val_loss: 0.5003 - learning_rate: 5.0000e-05
# Epoch 68/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8277 - loss: 0.5995 - val_accuracy: 0.8962 - val_loss: 0.5133 - learning_rate: 5.0000e-05
# Epoch 69/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8417 - loss: 0.5525 - val_accuracy: 0.9071 - val_loss: 0.5003 - learning_rate: 5.0000e-05
# Epoch 70/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8546 - loss: 0.5441 - val_accuracy: 0.9071 - val_loss: 0.4932 - learning_rate: 5.0000e-05
# Epoch 71/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.8523 - loss: 0.5395 - val_accuracy: 0.9071 - val_loss: 0.4829 - learning_rate: 5.0000e-05
# Epoch 72/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.8429 - loss: 0.5302 - val_accuracy: 0.9016 - val_loss: 0.4849 - learning_rate: 5.0000e-05
# Epoch 73/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.8429 - loss: 0.5320 - val_accuracy: 0.8962 - val_loss: 0.4763 - learning_rate: 5.0000e-05
# Epoch 74/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8605 - loss: 0.5254 - val_accuracy: 0.8907 - val_loss: 0.4858 - learning_rate: 5.0000e-05
# Epoch 75/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.8488 - loss: 0.5200 - val_accuracy: 0.8962 - val_loss: 0.4863 - learning_rate: 5.0000e-05
# Epoch 76/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.8441 - loss: 0.5199 - val_accuracy: 0.9071 - val_loss: 0.4712 - learning_rate: 5.0000e-05
# Epoch 77/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8535 - loss: 0.5152 - val_accuracy: 0.9180 - val_loss: 0.4653 - learning_rate: 5.0000e-05
# Epoch 78/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8488 - loss: 0.5014 - val_accuracy: 0.9126 - val_loss: 0.4677 - learning_rate: 5.0000e-05
# Epoch 79/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8535 - loss: 0.5179 - val_accuracy: 0.9071 - val_loss: 0.4501 - learning_rate: 5.0000e-05
# Epoch 80/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.8488 - loss: 0.5180 - val_accuracy: 0.9180 - val_loss: 0.4387 - learning_rate: 5.0000e-05
# Epoch 81/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8570 - loss: 0.5019 - val_accuracy: 0.9016 - val_loss: 0.4664 - learning_rate: 5.0000e-05
# Epoch 82/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8488 - loss: 0.5163 - val_accuracy: 0.9126 - val_loss: 0.4411 - learning_rate: 5.0000e-05
# Epoch 83/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8464 - loss: 0.5013 - val_accuracy: 0.8962 - val_loss: 0.4447 - learning_rate: 5.0000e-05
# Epoch 84/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8570 - loss: 0.4908 - val_accuracy: 0.9071 - val_loss: 0.4319 - learning_rate: 5.0000e-05
# Epoch 85/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8617 - loss: 0.4834 - val_accuracy: 0.9180 - val_loss: 0.4301 - learning_rate: 5.0000e-05
# Epoch 86/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.8499 - loss: 0.4806 - val_accuracy: 0.9126 - val_loss: 0.4179 - learning_rate: 5.0000e-05
# Epoch 87/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.8417 - loss: 0.4933 - val_accuracy: 0.9126 - val_loss: 0.4162 - learning_rate: 5.0000e-05
# Epoch 88/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.8523 - loss: 0.4922 - val_accuracy: 0.9126 - val_loss: 0.4286 - learning_rate: 5.0000e-05
# Epoch 89/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.8546 - loss: 0.4818 - val_accuracy: 0.9235 - val_loss: 0.4070 - learning_rate: 5.0000e-05
# Epoch 90/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.8581 - loss: 0.4774 - val_accuracy: 0.9126 - val_loss: 0.4082 - learning_rate: 5.0000e-05
# Epoch 91/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8523 - loss: 0.4650 - val_accuracy: 0.9126 - val_loss: 0.4042 - learning_rate: 5.0000e-05
# Epoch 92/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8875 - loss: 0.4464 - val_accuracy: 0.9126 - val_loss: 0.4067 - learning_rate: 5.0000e-05
# Epoch 93/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8710 - loss: 0.4382 - val_accuracy: 0.9180 - val_loss: 0.3958 - learning_rate: 5.0000e-05
# Epoch 94/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.8734 - loss: 0.4353 - val_accuracy: 0.9126 - val_loss: 0.3957 - learning_rate: 5.0000e-05
# Epoch 95/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8675 - loss: 0.4438 - val_accuracy: 0.9180 - val_loss: 0.3810 - learning_rate: 5.0000e-05
# Epoch 96/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8746 - loss: 0.4234 - val_accuracy: 0.9126 - val_loss: 0.3965 - learning_rate: 5.0000e-05
# Epoch 97/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.8722 - loss: 0.4560 - val_accuracy: 0.9126 - val_loss: 0.3956 - learning_rate: 5.0000e-05
# Epoch 98/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8992 - loss: 0.3882 - val_accuracy: 0.9071 - val_loss: 0.4025 - learning_rate: 5.0000e-05
# Epoch 99/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8687 - loss: 0.4446 - val_accuracy: 0.9180 - val_loss: 0.3810 - learning_rate: 5.0000e-05
# Epoch 100/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8957 - loss: 0.3858 - val_accuracy: 0.9235 - val_loss: 0.3775 - learning_rate: 5.0000e-05

# %%
plt.figure(figsize=(8, 4))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("CNN Training and Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("CNN Training and Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.tight_layout()
plt.show()

# %%
val_probs = model.predict(X_val)
val_pred = np.argmax(val_probs, axis=1)

val_acc = accuracy_score(y_val, val_pred)
val_f1 = f1_score(y_val, val_pred, average="macro")

print("Validation Accuracy:", val_acc)
print("Validation Macro-F1:", val_f1)

print(classification_report(
    y_val,
    val_pred,
    target_names=label_encoder.classes_
))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Validation Accuracy: 0.9234972677595629
# Validation Macro-F1: 0.9227109200657517
#                   precision    recall  f1-score   support
#
#      bird_sounds       0.96      0.96      0.96        27
#     construction       0.85      0.96      0.90        23
#    crowd_chatter       0.91      0.91      0.91        22
#        footsteps       0.95      0.91      0.93        22
# public_transport       0.88      0.95      0.91        22
#            siren       1.00      0.91      0.95        23
#          traffic       0.91      0.91      0.91        22
#       wind_trees       0.95      0.86      0.90        22
#
#         accuracy                           0.92       183
#        macro avg       0.93      0.92      0.92       183
#     weighted avg       0.93      0.92      0.92       183

# %%
test_probs = model.predict(X_test)
test_pred = np.argmax(test_probs, axis=1)

test_acc = accuracy_score(y_test, test_pred)
test_f1 = f1_score(y_test, test_pred, average="macro")

print("Test Accuracy:", test_acc)
print("Test Macro-F1:", test_f1)

print(classification_report(
    y_test,
    test_pred,
    target_names=label_encoder.classes_
))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Test Accuracy: 0.9289617486338798
# Test Macro-F1: 0.9270943145117674
#                   precision    recall  f1-score   support
#
#      bird_sounds       0.96      1.00      0.98        26
#     construction       0.91      0.95      0.93        22
#    crowd_chatter       0.95      0.87      0.91        23
#        footsteps       0.85      1.00      0.92        23
# public_transport       0.84      0.91      0.88        23
#            siren       1.00      1.00      1.00        22
#          traffic       0.95      0.91      0.93        23
#       wind_trees       1.00      0.76      0.86        21
#
#         accuracy                           0.93       183
#        macro avg       0.93      0.93      0.93       183
#     weighted avg       0.93      0.93      0.93       183

# %%
cm = confusion_matrix(y_test, test_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=label_encoder.classes_,
    yticklabels=label_encoder.classes_
)

plt.title("Log-mel Spectrogram + CNN (lr1e-4 + dropout = 0.5) Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
RESULTS_DIR = Path("../results")
MODELS_DIR = Path("../models")

RESULTS_DIR.mkdir(exist_ok=True)
MODELS_DIR.mkdir(exist_ok=True)

model.save(MODELS_DIR / "logmel_cnn_lr1e4_dropout50.keras")

cnn_results = {
    "model": "Log-mel CNN lr=1e-4 dropout=0.50",
    "experiment": "lr1e-4_dropout50",
    "features": "64-bin log-mel spectrogram",
    "validation_accuracy": val_acc,
    "validation_macro_f1": val_f1,
    "test_accuracy": test_acc,
    "test_macro_f1": test_f1,
    "architecture": "Conv32-Conv64-Conv128-GAP-Dense128",
    "learning_rate": 1e-4,
    "batch_size": 32,
    "dropout_dense": 0.50,
    "notes": "Lower learning rate and stronger dropout improved validation stability"
}

cnn_results_df = pd.DataFrame([cnn_results])
cnn_results_df.to_csv(
    RESULTS_DIR / "logmel_cnn_lr1e4_dropout50_results.csv",
    index=False
)

cnn_results_df
# Out:
#                               model        experiment  \
# 0  Log-mel CNN lr=1e-4 dropout=0.50  lr1e-4_dropout50
#
#                      features  validation_accuracy  validation_macro_f1  \
# 0  64-bin log-mel spectrogram             0.923497             0.922711
#
#    test_accuracy  test_macro_f1                        architecture  \
# 0       0.928962       0.927094  Conv32-Conv64-Conv128-GAP-Dense128
#
#    learning_rate  batch_size  dropout_dense  \
# 0         0.0001          32            0.5
#
#                                                notes
# 0  Lower learning rate and stronger dropout impro...

# %%
baseline_path = RESULTS_DIR / "mfcc_mlp_baseline_results.csv"
cnn_path = RESULTS_DIR / "logmel_cnn_lr1e4_dropout50_results.csv"

baseline_df = pd.read_csv(baseline_path)
cnn_df = pd.read_csv(cnn_path)

comparison_df = pd.concat([baseline_df, cnn_df], ignore_index=True)
comparison_df

plt.figure(figsize=(8, 4))
plt.bar(comparison_df["model"], comparison_df["test_macro_f1"])
plt.title("Model Comparison: Test Macro-F1")
plt.ylabel("Test Macro-F1")
plt.ylim(0, 1)
plt.tight_layout()
plt.show()
